# %% [markdown]
# Сорокін Олександр ФІТ 4-6
# Завдання 7 частина 2
# Завдання 2. Аналіз і візуалізація даних

# %% [markdown]
# Загрузити датасет, що містить інформацію про відвідуваність музеїв в різні роки.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\Italbey\Desktop\дз\мн\museum_visitors.csv", encoding='cp1251')
data
# Out:
#           Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0   2014-01-01        24778              4486                     1581
# 1   2014-02-01        18976              4172                     1785
# 2   2014-03-01        25231              7082                     3229
# 3   2014-04-01        26989              6756                     2129
# 4   2014-05-01        36883             10858                     3676
# 5   2014-06-01        29487              5751                     2121
# 6   2014-07-01        32378              5406                     2239
# 7   2014-08-01        37680              8619                     1769
# 8   2014-09-01        28473             61192                     1073
# 9   2014-10-01        27995              6488                     1979
# 10  2014-11-01        25691              4189                     2404
# 11  2014-12-01        18754              4339                     1319
# ...

# %% [markdown]
# Вивести перші 5 рядків датасету.

# %%
data5 = data.head(5)
data5
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# 3                                  2824
# 4                                 10694

# %% [markdown]
# Провести попередній аналіз даних (визначити розмір датасету, тип даних, кількість пропусків).

# %%
print("size", data.shape)
print("dtypes", data.dtypes)
print(data.isnull().sum())
# Out:
# size (59, 5)
# dtypes Date                                    object
# Avila Adobe                              int64
# Firehouse Museum                         int64
# Chinese American Museum                  int64
# America Tropical Interpretive Center     int64
# dtype: object
# Date                                    0
# Avila Adobe                             0
# Firehouse Museum                        0
# Chinese American Museum                 0
# America Tropical Interpretive Center    0
# dtype: int64

# %% [markdown]
# Перевірити наявність дублікатів. Якщо є, видалити їх і вивести розмір таблиці (без дублікатів).

# %%
duplicate = data[data.duplicated()]
print("Duplicate counter:", len(duplicate))
# Out:
# Duplicate counter: 0

# %% [markdown]
# Про які роки містить інформацію датасет.

# %%
year = data['Date'].str.split('-').str[0].unique()
for year in year:
    print(year)
# Out:
# 2014
# 2015
# 2016
# 2017
# 2018

# %% [markdown]
# Змінити назви столбців. Замінити великі букви на маленьки, пробіли на підкреслення (date, avila_adobe, firehouse_museum, chinese_american_museum, america_tropical_interpretive_center).

# %%
new_columns = {
    'Date' : 'date',
    'Avila Adobe' : 'avila_adobe',
    'Firehouse Museum' : 'firehouse_museum',
    'Chinese American Museum' : 'chinese_american_museum',
    'America Tropical Interpretive Center' : 'america_tropical_interpretive_center'
}
data.rename(columns=new_columns, inplace=True)
data
# Out:
#           date  avila_adobe  firehouse_museum  chinese_american_museum  \
# 0   2014-01-01        24778              4486                     1581
# 1   2014-02-01        18976              4172                     1785
# 2   2014-03-01        25231              7082                     3229
# 3   2014-04-01        26989              6756                     2129
# 4   2014-05-01        36883             10858                     3676
# 5   2014-06-01        29487              5751                     2121
# 6   2014-07-01        32378              5406                     2239
# 7   2014-08-01        37680              8619                     1769
# 8   2014-09-01        28473             61192                     1073
# 9   2014-10-01        27995              6488                     1979
# 10  2014-11-01        25691              4189                     2404
# 11  2014-12-01        18754              4339                     1319
# ...

# %% [markdown]
# Обчислити середню кількість відвідувачів для кожного музею протягом всього періоду.

# %%
vmean = round(data.drop(columns=['date']).mean())
print(vmean)
# Out:
# avila_adobe                             24062.0
# firehouse_museum                         6473.0
# chinese_american_museum                  2721.0
# america_tropical_interpretive_center     7107.0
# dtype: float64

# %% [markdown]
# Знайти мінімальну та максимальну кількість відвідувачів для кожного музею за 2018 рік

# %%
df_2018 = data[data['date'].str.startswith('2018')]
min_visit = df_2018.drop(columns=['date']).min()
max_visit = df_2018.drop(columns=['date']).max()

print("Max visit", max_visit)
print("Min Visit",min_visit)
# Out:
# Max visit avila_adobe                             25173
# firehouse_museum                         8013
# chinese_american_museum                  4960
# america_tropical_interpretive_center     5837
# dtype: int64
# Min Visit avila_adobe                             14718
# firehouse_museum                         3306
# chinese_american_museum                  2146
# america_tropical_interpretive_center     3180
# dtype: int64

# %% [markdown]
# Порівняти кількість відвідувачів музею "Avila Adobe" у літні й зимові місяці 2018 року

# %%
summer_m = [6,7,8]
winter_m= [12,1,2]
summer = df_2018[df_2018['date'].str.split('-').str[1].astype(int).isin(summer_m)]
winter = df_2018[df_2018['date'].str.split('-').str[1].astype(int).isin(winter_m)]

summer_visit = summer['avila_adobe'].sum()
winter_visit = winter['avila_adobe'].sum()

print("Visits on summer", summer_visit)
print("Visits on winter", winter_visit)
# Out:
# Visits on summer 66122
# Visits on winter 30983

# %% [markdown]
# Знайти кореляцію між кількістю відвідувачів в кожному з музеїв та датами у 2016 році

# %%
df_2016 = data[data['date'].str.startswith('2016')]
visit = ['avila_adobe','firehouse_museum','chinese_american_museum', 'america_tropical_interpretive_center']
visit_data = df_2016[visit]
corre = visit_data.corr()
print ("Correlation matrix visitors 2016:")
print(corre)
# Out:
# Correlation matrix visitors 2016:
#                                       avila_adobe  firehouse_museum  \
# avila_adobe                              1.000000          0.737200
# firehouse_museum                         0.737200          1.000000
# chinese_american_museum                  0.089054          0.553935
# america_tropical_interpretive_center     0.436561          0.247389
#
#                                       chinese_american_museum  \
# avila_adobe                                          0.089054
# firehouse_museum                                     0.553935
# chinese_american_museum                              1.000000
# america_tropical_interpretive_center                 0.443800
#
#                                       america_tropical_interpretive_center
# avila_adobe                                                       0.436561
# firehouse_museum                                                  0.247389
# ...

# %% [markdown]
# Побудувати теплокарту кореляції для попереднього завдання.

# %%
plt.figure(figsize=(16,10))
sns.heatmap(corre ,annot = True, cmap='icefire')
plt.title("Correlation heatmap")
plt.show()

# %% [markdown]
# Побудувати графік ліній для кожного музею, показуючи їхню відвідуваність протягом 2017 року

# %%
data_2017 = data[data['date'].str.startswith('2017')]
museum = ['avila_adobe','firehouse_museum','chinese_american_museum', 'america_tropical_interpretive_center']
visit = ['avila_adobe','firehouse_museum','chinese_american_museum', 'america_tropical_interpretive_center']
plt.figure(figsize=(12,6))
for museum in visit:
    sns.lineplot(data=data_2017, x='date', y=data_2017[museum], label=museum)
plt.title("@")
plt.xlabel("Date")
plt.ylabel("Count")
plt.xticks(rotation = 45)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Побудувати графіки розсіювання для кожного музею за 2018 рік

# %%
sns.pairplot(data=df_2018, vars=visit, height=2)
plt.suptitle("Pairplot Graphics")
plt.show()
# Out:
# D:\conda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Гістограма відвідуваності за місяцями кожного музею. Вивести 4 графіки: за 2014, 2015, 2016, 2017 роки. Графіки розташовані два зверху, два знизу, колір першого графіка - синій, другого зелений, третього жовтий, четвертого сірий.

# %%
df_2014 = data[data['date'].str.startswith('2014')]
df_2015 = data[data['date'].str.startswith('2015')]
fig,axes = plt.subplots(2,2, figsize =(12,6))
colors = ['blue','green','yellow','gray']
for i, data_year in enumerate([df_2014,df_2015,df_2016,data_2017]):
    summed_visit = data_year[visit].sum(axis=1)
    ax = axes[i//2, i % 2]
    sns.histplot(data=summed_visit,bins=30, kde=True, ax=ax, color=colors[i])
    ax.set_title(f"Year { i + 2014}")
    ax.set_xlabel("Summary visits")
    ax.set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# Висновок: У практичній роботі використовувалися методи аналізу та візуалізації даних.Я навичвся створювати теплокарту кількості відвідувачів в кожному музеї за певною датою, порівняльний графік лінії для кожного музею із показниками відвідуваності цих музеїв, графік розсіювання за певний проміжок часу.Також отримав навички побудови одночасно декількох гістограм за певний проміжок року.
